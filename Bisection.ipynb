# %% [markdown]
# <a href="https://colab.research.google.com/github/PrzemyslawSarnacki/NumericalMethods/blob/master/Bisection.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Implementujemy metodę Gaussa-Seidel'a w postaci funkcji

# %%
def bisection(f,a,b,N):
    # Check if using this method even makes sense 
    if f(a)*f(b) >= 0:
        print("Error")
        return None

    # We are copying values to new variables to avoid side effects
    a_ = a
    b_ = b
    # Iterate N times  
    for _ in range(1,N+1):
        # get average of range
        avg_val = (a_ + b_)/2
        # assign to variable in order to improve performance
        f_avg_val = f(avg_val)
        # Check a value
        if f(a_)*f_avg_val < 0:
            # if smaller than 0 assign avg to b
            a_ = a_
            b_ = avg_val
        # Check b value
        elif f(b_)*f_avg_val < 0:
            # if smaller than 0 assign avg to a
            a_ = avg_val
            b_ = b_
        # Check if we got exact root 
        elif f_avg_val == 0:
            print("Exactly this value is correct!")
            return avg_val
        else:
            print("Error1")
            return None
    # after every iteration return average of a and b
    return (a_ + b_)/2

# %%
def sine(x):
    """
    docstring
    """
    return math.sin(3*x) + math.cos(10*x)

# %%
points = [bisection(sine, i,i+1, 25) for i in range(4)]
# Out:
# Error

# %%
bisection(sine,2,3,25)
# Out:
# Error

# %%
points
# Out:
# [0.8458134084939957, 1.8124573081731796, None, 3.2624231427907944]

# %%
sns.set_style("whitegrid")
original_sine = np.array([sine(i) for i in np.arange(0, 5, 0.01)])
sns.lineplot(np.arange(0,5,0.01), original_sine)
for point in points:
    if point != None:
        plt.scatter(point, 0, marker='o', s=25)
