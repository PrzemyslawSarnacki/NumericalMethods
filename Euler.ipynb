# %% [markdown]
# <a href="https://colab.research.google.com/github/PrzemyslawSarnacki/NumericalMethods/blob/master/LeastSquares.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import scipy.interpolate
from numpy.polynomial.polynomial import Polynomial

# %%
def func(x_, y_):
    """
    docstring
    """
    return 3 * x_ * y_ ** 2

# %%
h = 0.1
y0 = 0.5
x0 = 1

yi = y0
xi = x0
for i in np.arange(0, 0.4, h):
    xi = x0 + i
    print(xi)
    yi = yi + h * (3 * xi * yi ** 2)
    print(yi)
# Out:
# 1.0
# 0.575
# 1.1
# 0.6841062499999999
# 1.2
# 0.8525867400640623
# 1.3
# 1.1360793583039577

# %%
func(x0 + 0.5 * h, y0 + 0.5 * h * (3 * x0 * y0 ** 2))
n1 = y0 + h * func(x0 + 0.5 * h, y0 + 0.5 * h * (3 * x0 * y0 ** 2))
n1
# Out:
# 0.59100546875

# %%
yi = y0
for i in np.arange(0, 0.4, h):
    xi = x0 + i
    # yi = (y0+i)
    print(f"{xi=}")
    print(f"{yi=}")
    fi = func(xi + 0.5 * h, yi + 0.5 * h * (3 * xi * yi ** 2))
    print(f"f({xi}+0.5*{h}, {yi}+0.5*h*(3*{xi}*{yi}**2))")
    print(f"ni ={yi} + {h}*{fi}")
    yi = yi + h * fi
    print(yi)
# Out:
# xi=1.0
# yi=0.5
# f(1.0+0.5*0.1, 0.5+0.5*h*(3*1.0*0.5**2))
# ni =0.5 + 0.1*0.9100546875000001
# 0.59100546875
# xi=1.1
# yi=0.59100546875
# f(1.1+0.5*0.1, 0.59100546875+0.5*h*(3*1.1*0.59100546875**2))
# ni =0.59100546875 + 0.1*1.4515223837972917
# 0.7361577071297292
# xi=1.2
# yi=0.7361577071297292
# f(1.2+0.5*0.1, 0.7361577071297292+0.5*h*(3*1.2*0.7361577071297292**2))
# ni =0.7361577071297292 + 0.1*2.6064887112723594
# 0.9968065782569651
# xi=1.3
# yi=0.9968065782569651
# f(1.3+0.5*0.1, 0.9968065782569651+0.5*h*(3*1.3*0.9968065782569651**2))
# ni =0.9968065782569651 + 0.1*5.740634317300027
# 1.570870009986968

# %% [markdown]
# Implementacja funkcji liczącej współczynniki metody wymiernej

# %% [markdown]
# Implementacja wyłącznie na wartościach liczbowych (wynikiem jest tablica zawierająca wyniki w przedziale (od min zbioru do max) )

# %% [markdown]
# Przetestujmy funkcję liczącą współczynniki (jak widzimy wynikiem jest macierz zawierająca współczynniki)

# %% [markdown]
# Przetestujmy funkcję numeryczną

# %% [markdown]
# Porównajmy wyniki te z funkcją otrzymaną symbolicznie

# %% [markdown]
# Sprawdźmy wyniki przykładowej funkcji z biblioteki SciPy (jest to aproksymacja metodą taylora)

# %% [markdown]
# Porównanie powyższych działań na wykresie

# %%
plt.style.use("fivethirtyeight")

plt.plot(interval, leastsq(x_arr, y_arr, 2), color="yellow")
plt.plot(interval, poly(interval), linestyle="dashed")
plt.plot(x_arr, y_arr, "o", color="lime")
plt.title(
    "Porównanie Implementacji do wyniku z biblioteki SciPy\n do funkcji \noraz punktów ze zbioru par"
)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend(["Implementacja", "SciPy", "Punkty"])

# %% [markdown]
# Jak widzimy wyniki z implementacją z biblioteki SciPy pokrywają się.
