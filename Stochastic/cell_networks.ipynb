# %%
 import pandas as pd
 import numpy as np
 import seaborn as sns

# %%
df_3g = pd.read_csv("C:/Users/Przemyslaw/Downloads/3g/3g/3g.csv")

# %%
df_3g.head()
# Out:
#   radiotype  radio  mcc  mnc   area    cellid  unit        lat        lon  \
# 0       LTE    LTE  260    3  58020  46428440   150  52.271069  20.965581
# 1      UMTS  HSPA+  260    3  58020  42082457   120  52.272240  20.965041
# 2      UMTS  HSPA+  260    3  58020  42082450   324  52.272121  20.964967
# 3      UMTS  HSUPA  260    3  58020  42082459   499  52.270123  20.964307
# 4       LTE    LTE  260    3  58020  46428440   150  52.269056  20.962806
#
#       acc  sim  signal  extra          time  speed  bearing    alt   api  \
# 0  1000.0  NaN     NaN    NaN           NaN    NaN      NaN    NaN   NaN
# 1  2263.0  NaN     NaN    NaN           NaN    NaN      NaN    NaN   NaN
# 2  1800.0  NaN     NaN    NaN           NaN    NaN      NaN    NaN   NaN
# 3  5491.0  NaN     NaN    NaN           NaN    NaN      NaN    NaN   NaN
# 4    15.1  1.0  -107.0    2.0  1.607528e+12    0.0      0.0  133.3  28.0
#
#              device
# 0               NaN
# 1               NaN
# ...

# %%
sns.regplot(data=df_3g, x="signal", y="speed")
# Out:
# <AxesSubplot:xlabel='signal', ylabel='speed'>

# %%
sns.lineplot(data=df_3g, x=df_3g.index, y="speed", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='speed'>

# %%
sns.lineplot(data=df_3g, x=df_3g.index, y="acc", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='acc'>

# %%
sns.lineplot(data=df_3g, x=df_3g.index, y="signal", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='signal'>

# %%
sns.lineplot(data=df_3g, x=df_3g.index, y="cellid", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='cellid'>

# %%
sns.lineplot(data=df_3g, x=df_3g.index, y="unit", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='unit'>

# %%
df_2g = pd.read_csv("C:/Users/Przemyslaw/Downloads/3g/2g/2g.csv")

# %%
df_2g.head()
# Out:
#    sim radiotype radio  mcc  mnc   area  cellid  unit        lat        lon  \
# 0    1       GSM  EDGE  260    3  58060   29706   NaN  52.360959  21.280234
# 1    1       GSM  EDGE  260    3  58060   29706   NaN  52.360959  21.280234
# 2    1       GSM  EDGE  260    3  58060   29706   NaN  52.360962  21.280234
# 3    1       GSM  EDGE  260    3  58060   29706   NaN  52.360959  21.280234
# 4    1       GSM  EDGE  260    3  58060   29706   NaN  52.360962  21.280234
#
#    signal  extra   acc           time  speed  bearing    alt  api  \
# 0     -91    NaN  19.6  1607618086901    0.1    331.9  128.6   28
# 1     -91    NaN  19.6  1607618086901    0.1    331.9  128.6   28
# 2     -91    NaN  19.9  1607618092475    0.1    345.8  128.6   28
# 3     -91    NaN  19.6  1607618086901    0.1    331.9  128.6   28
# 4     -91    NaN  19.9  1607618092475    0.1    345.8  128.6   28
#
#              device
# 0  Samsung_SM-G960F
# 1  Samsung_SM-G960F
# 2  Samsung_SM-G960F
# 3  Samsung_SM-G960F
# ...

# %%
sns.regplot(data=df_2g, x="signal", y="speed")
# Out:
# <AxesSubplot:xlabel='signal', ylabel='speed'>

# %%
sns.lineplot(data=df_2g, x=df_2g.index, y="signal", hue="radiotype")

# %%
sns.lineplot(data=df_2g, x=df_2g.index, y="cellid", hue="radiotype")
# Out:
# <AxesSubplot:ylabel='cellid'>

# %%
sns.lineplot(data=df_2g, x=df_2g.index, y="speed", hue="radio")
# Out:
# <AxesSubplot:ylabel='speed'>
